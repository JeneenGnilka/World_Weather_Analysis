# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID              City      Lat       Lng  Max Temp  Humidity  \
# 0        0           chonchi -42.6128  -73.8092     12.56        58
# 1        1          ulaangom  49.9811   92.0667      7.58        65
# 2        2           dudinka  69.4058   86.1778      1.49        93
# 3        3  flying fish cove -10.4217  105.6791     24.82        94
# 4        4        simanggang   1.2472  111.4528     23.99       100
#
#    Cloudiness  Wind Speed Country        Date
# 0          92        2.28      CL  1697314988
# 1         100        1.31      MN  1697314988
# 2         100        6.71      RU  1697314872
# 3         100        4.63      CX  1697314989
# 4          96        1.03      MY  1697314990

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng", 
    "Lat", 
    global_extent=True,
    frame_height=450, 
    tiles = "OSM",
    size = "Humidity",
    scale = 0.5,
    color = "City",
)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
filter_cities_df = city_data_df.query("`Max Temp` >= 21 and `Max Temp` < 24 and `Humidity` >=40 and `Humidity` < 80")

# Drop any rows with null values
# filter_cities_df = filter_cities_df.dropna()

# Display sample data
filter_cities_df
# Out:
#      City_ID              City      Lat       Lng  Max Temp  Humidity  \
# 15        15         adamstown -25.0660 -130.1015     21.11        69
# 20        20            gignac  43.6520    3.5509     21.53        62
# 22        22     port mathurin -19.6833   63.4167     22.87        65
# 96        96   arraial do cabo -22.9661  -42.0278     21.98        78
# 184      184  praia da vitoria  38.7333  -27.0667     22.14        73
# 213      213         inhambane -23.8650   35.3833     22.25        73
# 312      312             pisco -13.7000  -76.2167     21.03        68
# 336      336      saint-pierre -21.3393   55.4781     22.82        73
# 360      360       shasta lake  40.6804 -122.3708     21.97        44
# 383      383      as salamiyah  35.0113   37.0532     22.49        65
# 384      384           mungeli  22.0667   81.6833     22.76        64
# 403      403      mersa matruh  31.3525   27.2453     22.11        68
# 432      432      port hedland -20.3167  118.5667     23.03        60
# 510      510  margahayukencana  -6.9708  107.5675     23.09        76
# 534      534            tobruk  32.0836   23.9764     22.62        68
# 563      563           mahenge  -8.6833   36.7167     21.60        57
#
#      Cloudiness  Wind Speed Country        Date
# 15           94        0.76      PN  1697314992
# 20           42        4.33      FR  1697314992
# 22            0        5.46      MU  1697314992
# 96          100        5.14      BR  1697315012
# 184          40        2.51      PT  1697315029
# 213          79        6.41      MZ  1697315032
# 312           0        9.26      PE  1697315043
# 336           0        0.00      RE  1697315046
# 360         100        0.45      US  1697315065
# 383          43        4.13      SY  1697315073
# 384           1        2.00      IN  1697315073
# 403          40        4.12      EG  1697315077
# 432          14        2.57      AU  1697315079
# 510          98        0.67      ID  1697315090
# 534           1        4.91      LY  1697315092
# 563          38        1.79      TZ  1697315095

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
selected_columns = ['City', 'Country', 'Lat', 'Lng', 'Humidity']
hotel_df = filter_cities_df[selected_columns].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df
# Out:
#                  City Country      Lat       Lng  Humidity Hotel Name
# 15          adamstown      PN -25.0660 -130.1015        69
# 20             gignac      FR  43.6520    3.5509        62
# 22      port mathurin      MU -19.6833   63.4167        65
# 96    arraial do cabo      BR -22.9661  -42.0278        78
# 184  praia da vitoria      PT  38.7333  -27.0667        73
# 213         inhambane      MZ -23.8650   35.3833        73
# 312             pisco      PE -13.7000  -76.2167        68
# 336      saint-pierre      RE -21.3393   55.4781        73
# 360       shasta lake      US  40.6804 -122.3708        44
# 383      as salamiyah      SY  35.0113   37.0532        65
# 384           mungeli      IN  22.0667   81.6833        64
# 403      mersa matruh      EG  31.3525   27.2453        68
# 432      port hedland      AU -20.3167  118.5667        60
# 510  margahayukencana      ID  -6.9708  107.5675        76
# 534            tobruk      LY  32.0836   23.9764        68
# 563           mahenge      TZ  -8.6833   36.7167        57

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation", 
    "apiKey": geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from the DataFrame
    latitude = row['Lat']
    longitude = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set the base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make an API request using the params dictionary
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df


# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row['Lat']
    longitude = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# adamstown - nearest hotel: No hotel found
# gignac - nearest hotel: Le jardin suspendu
# port mathurin - nearest hotel: Résidence Véronia
# arraial do cabo - nearest hotel: No hotel found
# praia da vitoria - nearest hotel: Salles
# inhambane - nearest hotel: Hotel de Inhambane
# pisco - nearest hotel: No hotel found
# saint-pierre - nearest hotel: Tropic Hotel
# shasta lake - nearest hotel: Shasta Dam Motel
# as salamiyah - nearest hotel: فندق السلام
# mungeli - nearest hotel: No hotel found
# mersa matruh - nearest hotel: صقور
# port hedland - nearest hotel: The Esplanade Hotel
# margahayukencana - nearest hotel: Hostel Intech Kopo 538
# tobruk - nearest hotel: فندق زهرة البطنان -طبرق
# mahenge - nearest hotel: No hotel found
# Starting hotel search
# adamstown - nearest hotel: No hotel found
# gignac - nearest hotel: Le jardin suspendu
# port mathurin - nearest hotel: Résidence Véronia
# arraial do cabo - nearest hotel: No hotel found
# praia da vitoria - nearest hotel: Salles
# inhambane - nearest hotel: Hotel de Inhambane
# pisco - nearest hotel: No hotel found
# saint-pierre - nearest hotel: Tropic Hotel
# shasta lake - nearest hotel: Shasta Dam Motel
# as salamiyah - nearest hotel: فندق السلام
# mungeli - nearest hotel: No hotel found
# mersa matruh - nearest hotel: صقور
# port hedland - nearest hotel: The Esplanade Hotel
# margahayukencana - nearest hotel: Hostel Intech Kopo 538
# tobruk - nearest hotel: فندق زهرة البطنان -طبرق
# mahenge - nearest hotel: No hotel found
#                  City Country      Lat       Lng  Humidity  \
# 15          adamstown      PN -25.0660 -130.1015        69
# 20             gignac      FR  43.6520    3.5509        62
# 22      port mathurin      MU -19.6833   63.4167        65
# 96    arraial do cabo      BR -22.9661  -42.0278        78
# 184  praia da vitoria      PT  38.7333  -27.0667        73
# 213         inhambane      MZ -23.8650   35.3833        73
# 312             pisco      PE -13.7000  -76.2167        68
# 336      saint-pierre      RE -21.3393   55.4781        73
# 360       shasta lake      US  40.6804 -122.3708        44
# 383      as salamiyah      SY  35.0113   37.0532        65
# 384           mungeli      IN  22.0667   81.6833        64
# 403      mersa matruh      EG  31.3525   27.2453        68
# 432      port hedland      AU -20.3167  118.5667        60
# 510  margahayukencana      ID  -6.9708  107.5675        76
# 534            tobruk      LY  32.0836   23.9764        68
# 563           mahenge      TZ  -8.6833   36.7167        57
#
#                   Hotel Name
# 15            No hotel found
# 20        Le jardin suspendu
# 22         Résidence Véronia
# 96            No hotel found
# 184                   Salles
# 213       Hotel de Inhambane
# 312           No hotel found
# 336             Tropic Hotel
# 360         Shasta Dam Motel
# 383              فندق السلام
# 384           No hotel found
# 403                     صقور
# 432      The Esplanade Hotel
# 510   Hostel Intech Kopo 538
# 534  فندق زهرة البطنان -طبرق
# 563           No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng", 
    "Lat", 
    global_extent=True,
    frame_height=450,
    tiles = "OSM",
    size = "Humidity",
    scale = 0.5,
    color = "City",
    hover_cols= ['Lng', 'Lat', 'City', 'Humidity', 'Hotel Name', 'Country']
)

# Display the map
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
